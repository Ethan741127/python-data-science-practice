# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.style.use('ggplot')

#pandas作圖不使用plt.show()，若要顯示在Jupyter Notebook上，需先執行以下程式碼：（%是在ipython shell中執行command line的意思）
# %matplotlib inline


df = pd.DataFrame(np.random.rand(6,4),index=['bar1','bar2','bar3','bar4','bar5','bar6'],columns=['A','B','C','D'])
df
# Out:
#              A         B         C         D
# bar1  0.529299  0.526041  0.309194  0.219708
# bar2  0.124756  0.075090  0.638839  0.937324
# bar3  0.173468  0.864699  0.510334  0.592184
# bar4  0.487734  0.275189  0.842265  0.939967
# bar5  0.410434  0.407556  0.244198  0.243160
# bar6  0.977435  0.399422  0.620257  0.084706

# %%
df.plot(kind='bar',title='test',figsize=(8,6))

# %%
 df.plot(kind='bar',title='test',figsize=(8,6),stacked=True)

# %%
 df.plot(kind='area',title='test',figsize=(8,6))

# %%
df.plot(kind='area',title='面積圖',figsize=(8,6),stacked=False)

# %%
df.plot(kind='line',title='折線圖',figsize=(6,4))

# %%
df.plot(kind='line',style='--',title='折線圖',figsize=(6,4))

# %%
df.plot(kind='line',style='-o',title='折線圖',figsize=(6,4))

# %%
df2 = pd.DataFrame({'score':np.random.normal(70,10,200)})
df2.plot(kind='hist',title='直方圖',figsize=(6,4))

# %%
df2.plot(kind='kde',title='機率密度圖')
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df['A'].plot(kind='pie',title='圓餅圖',figsize=(4,4))
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df3 = pd.DataFrame({'A':np.random.randn(1000),'B':np.random.randn(1000)})
df3[:10]
# Out:
#           A         B
# 0  1.225041  0.321541
# 1  2.073408  2.256113
# 2 -0.652587 -0.035285
# 3 -1.332342 -0.246996
# 4  0.338917  0.672410
# 5  0.474836 -0.429950
# 6 -0.277049 -0.142849
# 7  1.513680 -0.854692
# 8  0.447641  0.210027
# 9 -1.094025  1.781938

# %%
plt.rcParams['axes.unicode_minus']=False #正常顯示負號
df3.plot(kind='hexbin',title='蜂窩圖',x='A',y='B',gridsize=10)
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df4 = pd.DataFrame({'A':np.random.randn(100),'B':np.random.randn(100),'C':np.random.randn(100)})
df4[:10]
# Out:
#           A         B         C
# 0  0.323413  0.109810 -0.269058
# 1 -0.074630 -0.147778  0.655961
# 2  0.930387  0.029286 -0.692073
# 3 -0.217957  1.005781  0.088784
# 4  0.660229 -0.723635  0.107800
# 5  1.056547 -3.063192 -0.023048
# 6 -0.674581 -1.416546 -0.319345
# 7  1.974739  0.576455  1.050950
# 8 -0.125775  1.323714 -0.177123
# 9 -2.353653  0.347989 -0.451600

# %%
df4.plot(kind='scatter',title='散佈圖',figsize=(6,4),x='A',y='B')
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df4.plot(kind='scatter',title='散佈圖',figsize=(6,4),x='A',y='B',c='C')
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df.plot(kind='line',title='折線圖',figsize=(8,6),subplots=True,style={'A':'-','B':'--','C':'-o','D':'-.'})
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1995d9e8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a199efb70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a19a22128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a19a486a0>],
#       dtype=object)
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ax = df.plot(kind='bar',figsize=(6,4),stacked=True)
df.plot(kind='line',style='--',figsize=(6,4),ax=ax)
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ax=df2.plot(kind='hist',figsize=(8,6),stacked=True)
df2.plot(kind='kde',style='--',figsize=(8,6))
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
