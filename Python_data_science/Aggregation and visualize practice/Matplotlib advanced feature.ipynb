# %% [markdown]
# 1. X軸雙變項作圖（折線圖、長條圖）

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# 調整作圖大小
fig = plt.figure(figsize=(8,5))

x = [6,7,8,9,10]
y = [123,432,823,192,12]
x2 = [1,2,3,4,5]
y2 = [432,12,432,847,223]

plt.plot(x,y,'+')
plt.plot(x2,y2,'-')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('ggplot')

fig = plt.figure(figsize=(4,3))

x = [1,2,3,4,5]
y = [123,432,823,192,12]
x2 = [1,2,3,4,5]
y2 = [432,12,432,847,223]

plt.bar(np.array(x)-0.2,y,color = 'g',width=0.4,align='center')
plt.bar(np.array(x2)+0.2,y2,color = 'b',width=0.4,align='center')
plt.show()

# %%
np.array(x)-0.2
# Out:
# array([0.8, 1.8, 2.8, 3.8, 4.8])

# %% [markdown]
# 2. 作圖風格
#
# 查查看所有的風格選擇

# %%
print(plt.style.available)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %%
plt.style.use('dark_background')

fig = plt.figure(figsize=(4,3))

x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.bar(x,y,align='center')
plt.show()

# %%
plt.style.use('grayscale')

fig = plt.figure(figsize=(4,3))

x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.bar(x,y,align='center')
plt.show()

# %%
plt.style.use('classic')

fig = plt.figure(figsize=(4,3))

x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.bar(x,y,align='center')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(4,3))

x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.bar(x,y,align='center')
plt.show()

# %% [markdown]
# 3. 標題、X、Y軸名稱（中文處理與字體選擇）

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(4,3))
x = [1,2,3,4,5]
y = [123,432,823,192,12]



plt.bar(x,y,align='center')
plt.title('Test') #標題名稱
plt.xlabel('X') #X軸名稱
plt.ylabel('Y') #Y軸名稱
plt.xticks(x, ['A','B','C','D','刻度E']) #X軸刻度名稱

plt.show()
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import matplotlib
[f.name for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['STIXSizeTwoSym',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'cmsy10',
#  'cmb10',
#  'STIXGeneral',
#  'DejaVu Sans Display',
#  'cmtt10',
#  'cmmi10',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'cmex10',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'DejaVu Serif Display',
#  'cmr10',
#  'STIXSizeFourSym',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'STIXSizeOneSym',
#  'cmss10',
#  'STIXSizeFiveSym',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'Hoefler Text',
#  'Courier New',
#  'Trebuchet MS',
#  '.SF Compact Text',
#  'Meslo LG L DZ for Powerline',
#  'Microsoft Sans Serif',
#  'STIXIntegralsSm',
#  '.SF Compact Rounded',
#  'System Font',
#  'System Font',
#  'Arial',
#  'System Font',
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(4,3))
x = [1,2,3,4,5]
y = [123,432,823,192,12]

font1 = {'fontname':'Times New Roman'}
font2 = {'fontname':'Arial'}

plt.bar(x,y,align='center')
plt.title('Title',**font1) #標題名稱
plt.xlabel('X bar',**font1) #X軸名稱
plt.ylabel('Y bar',**font1) #Y軸名稱
plt.xticks(x, ['tick A','tick B','tick C','tick D','tick E'],**font2) #X軸刻度名稱

plt.show()
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# 4. 多圖合一

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

plt.figure(figsize=(6,6))
x = [1,2,3,4,5]
y = [123,432,823,192,12]

ax1 = plt.subplot(211) #2x1的第1張圖
plt.plot(x,y,'-')
plt.setp(ax1.get_xticklabels(), visible=False) #不顯示x軸ticks
plt.subplot(212,sharex=ax1) #2x1的第2張圖
plt.bar(x,y,align='center')
plt.show()
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(5,3))
plt.plot(x,y,'-')
plt.bar(x,y,align='center')
plt.show()
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# 5. 折線圖種類

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(4,3))
x = [1,2,3,4,5]
y = [123,432,823,192,12]
plt.plot(x,y,'-')
plt.show()
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
fig = plt.figure(figsize=(4,3))
#plt.plot(x,y,'g--') #green
plt.plot(x,y,color='g',linestyle='--')
plt.show()
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
fig = plt.figure(figsize=(4,3))
plt.plot(x,y,'b-.') #blue
plt.show()
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
fig = plt.figure(figsize=(4,3))
plt.plot(x,y,'b-o') #blue
plt.show()
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# 不連線的折線圖 => 散佈圖
fig = plt.figure(figsize=(4,3))
plt.plot(x,y,'*') #blue
plt.show()
# Out:
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
