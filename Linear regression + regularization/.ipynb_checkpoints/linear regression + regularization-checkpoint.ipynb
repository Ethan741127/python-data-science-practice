# %% [markdown]
# 一、資料匯入

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['font.family']='SimHei'#顯示中文(for Mac)
plt.rcParams['axes.unicode_minus']=False#正常顯示負號

pd.set_option('display.max_columns',50)#設定pandas最多顯示出50個欄位資訊
pd.set_option('display.html.table_schema',True)
df_ml=pd.read_csv('/Users/ethan/Desktop/AI/python資料科學/python-data-science-practice/Linear regression + regularization/f50fa20af9d7c1a411590450d7531ae757/tw_house.csv',encoding='big5')
df_ml.sample(5)#隨機取其中5筆資料
# Out:
#     鄉鎮市區  土地移轉總面積平方公尺  建物移轉總面積平方公尺  單價每平方公尺  建物現況格局-房  建物現況格局-廳  建物現況格局-衛  \
# 572  萬華區        12.10        70.01   101843         2         2         1
# 548  信義區        23.69       119.87   172687         3         2         2
# 524  大同區        15.25       159.67   197622         3         2         2
# 284  大同區        17.85       112.93   154950         2         1         1
# 481  中山區        21.04        78.91   164745         3         2         2
#
#      車位移轉總面積平方公尺    車位總價元  屋齡  建築完成年  交易年     總價元  中山區  中正區  信義區  內湖區  北投區  \
# 572         0.00        0  38     68  106   713.0    0    0    0    0    0
# 548         0.00        0  28     78  106  2070.0    0    0    1    0    0
# 524        16.72  1550000   1    105  106  2980.0    0    0    0    0    0
# 284        20.26        0  22     84  106  1750.0    0    0    0    0    0
# 481         0.00        0  35     71  106  1300.0    1    0    0    0    0
#
#      南港區  士林區  大同區  大安區  文山區  松山區  萬華區
# 572    0    0    0    0    0    0    1
# 548    0    0    0    0    0    0    0
# 524    0    0    1    0    0    0    0
# 284    0    0    1    0    0    0    0
# 481    0    0    0    0    0    0    0

# %% [markdown]
# 二、檢查特徵相關性及線性關係

# %%
# 把DataFrame加上highlight背景色
def highlight_highcorr(s):
    is_high = ((s>=0.6) & (s<1))#Series condition setting
    return ['background-color: red' if v else '' for v in is_high]

# %%
df_ml.corr().round(3).style.apply(highlight_highcorr)#round(3)小數點第三位
# Out:
# <style  type="text/css" >
#     #T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col1 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col0 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col6 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col7 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col11 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row3_col4 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row3_col5 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row4_col3 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row5_col3 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row6_col1 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row6_col7 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row6_col11 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row7_col1 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row7_col6 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row7_col11 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row11_col1 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row11_col6 {
#             background-color:  red;
#         }    #T_ff582b70_c3ed_11ea_92a0_acde48001122row11_col7 {
#             background-color:  red;
#         }</style>
# <table id="T_ff582b70_c3ed_11ea_92a0_acde48001122" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >土地移轉總面積平方公尺</th>
#         <th class="col_heading level0 col1" >建物移轉總面積平方公尺</th>
#         <th class="col_heading level0 col2" >單價每平方公尺</th>
#         <th class="col_heading level0 col3" >建物現況格局-房</th>
#         <th class="col_heading level0 col4" >建物現況格局-廳</th>
#         <th class="col_heading level0 col5" >建物現況格局-衛</th>
#         <th class="col_heading level0 col6" >車位移轉總面積平方公尺</th>
#         <th class="col_heading level0 col7" >車位總價元</th>
#         <th class="col_heading level0 col8" >屋齡</th>
#         <th class="col_heading level0 col9" >建築完成年</th>
#         <th class="col_heading level0 col10" >交易年</th>
#         <th class="col_heading level0 col11" >總價元</th>
#         <th class="col_heading level0 col12" >中山區</th>
#         <th class="col_heading level0 col13" >中正區</th>
#         <th class="col_heading level0 col14" >信義區</th>
#         <th class="col_heading level0 col15" >內湖區</th>
#         <th class="col_heading level0 col16" >北投區</th>
#         <th class="col_heading level0 col17" >南港區</th>
#         <th class="col_heading level0 col18" >士林區</th>
#         <th class="col_heading level0 col19" >大同區</th>
#         <th class="col_heading level0 col20" >大安區</th>
#         <th class="col_heading level0 col21" >文山區</th>
#         <th class="col_heading level0 col22" >松山區</th>
#         <th class="col_heading level0 col23" >萬華區</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ff582b70_c3ed_11ea_92a0_acde48001122level0_row0" class="row_heading level0 row0" >土地移轉總面積平方公尺</th>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col0" class="data row0 col0" >1</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col1" class="data row0 col1" >0.678</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col2" class="data row0 col2" >0.069</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col3" class="data row0 col3" >0.34</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col4" class="data row0 col4" >0.22</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col5" class="data row0 col5" >0.242</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col6" class="data row0 col6" >0.39</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col7" class="data row0 col7" >0.348</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col8" class="data row0 col8" >-0.068</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col9" class="data row0 col9" >0.068</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col10" class="data row0 col10" >-0.009</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col11" class="data row0 col11" >0.515</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col12" class="data row0 col12" >-0.207</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col13" class="data row0 col13" >-0.107</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col14" class="data row0 col14" >0.039</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col15" class="data row0 col15" >0.157</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col16" class="data row0 col16" >0.06</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col17" class="data row0 col17" >0.08</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col18" class="data row0 col18" >0.121</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col19" class="data row0 col19" >-0.081</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col20" class="data row0 col20" >-0.056</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col21" class="data row0 col21" >0.116</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col22" class="data row0 col22" >-0.049</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row0_col23" class="data row0 col23" >-0.109</td>
#     </tr>    <tr>
#         <th id="T_ff582b70_c3ed_11ea_92a0_acde48001122level0_row1" class="row_heading level0 row1" >建物移轉總面積平方公尺</th>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col0" class="data row1 col0" >0.678</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col1" class="data row1 col1" >1</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col2" class="data row1 col2" >0.272</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col3" class="data row1 col3" >0.197</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col4" class="data row1 col4" >0.06</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col5" class="data row1 col5" >0.153</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col6" class="data row1 col6" >0.736</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col7" class="data row1 col7" >0.625</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col8" class="data row1 col8" >-0.411</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col9" class="data row1 col9" >0.411</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col10" class="data row1 col10" >-0.083</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col11" class="data row1 col11" >0.862</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col12" class="data row1 col12" >-0.092</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col13" class="data row1 col13" >-0.021</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col14" class="data row1 col14" >0.033</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col15" class="data row1 col15" >0.121</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col16" class="data row1 col16" >0.018</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col17" class="data row1 col17" >0.092</td>
#         <td id="T_ff582b70_c3ed_11ea_92a0_acde48001122row1_col18" class="data row1 col18"

# %% [markdown]
# 散佈圖矩陣

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df_ml[['建物移轉總面積平方公尺','土地移轉總面積平方公尺','建物現況格局-房','屋齡','交易年']],figsize=(20,20),color='b')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc43726b9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc437347438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc4373d6ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc43742f198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc437453828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc437453860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc4374a2588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc4374c8c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc4374f52e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc437519978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc437546048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc4375576d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc43756dd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc43759c438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc4375c2ac8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc4375f4198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc43761c828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc437643eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc437675588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc43769bc18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc4376cf2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc4376f5978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc437729048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc43774f6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc437777d68>]],
#       dtype=object)
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# 三、建模前預處理
#
# 切分訓練及測試資料

# %%
from sklearn.model_selection import train_test_split

x=df_ml[['建物移轉總面積平方公尺','土地移轉總面積平方公尺','單價每平方公尺','建物現況格局-房','建物現況格局-廳','建物現況格局-衛','車位移轉總面積平方公尺','車位總價元','屋齡','建築完成年','交易年','中山區','中正區','信義區','內湖區','北投區','南港區','士林區','大同區','大安區','文山區','松山區','萬華區']]
y=df_ml[['總價元']]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3) # 30% for testing, 70% for training
x_train.head()
# Out:
#      建物移轉總面積平方公尺  土地移轉總面積平方公尺  單價每平方公尺  建物現況格局-房  建物現況格局-廳  建物現況格局-衛  \
# 181        89.38        13.96   258223         0         0         0
# 114        87.51        25.11   166322         2         1         2
# 604        99.20        24.81   142137         3         2         1
# 232       124.34        12.61    95544         3         2         2
# 364        98.44        17.89   140187         2         1         1
#
#      車位移轉總面積平方公尺  車位總價元  屋齡  建築完成年  交易年  中山區  中正區  信義區  內湖區  北投區  南港區  士林區  \
# 181        17.43      0   2    104  106    0    1    0    0    0    0    0
# 114         0.00      0   1    105  106    0    0    0    0    0    0    1
# 604         0.00      0  33     73  106    0    0    0    1    0    0    0
# 232         0.00      0  30     76  106    0    0    0    0    0    0    0
# 364         0.00      0  22     84  106    0    0    0    0    1    0    0
#
#      大同區  大安區  文山區  松山區  萬華區
# 181    0    0    0    0    0
# 114    0    0    0    0    0
# 604    0    0    0    0    0
# 232    0    0    0    0    1
# 364    0    0    0    0    0

# %% [markdown]
# 標準化

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)
x_std = sc.transform(x)

# %% [markdown]
# 產生高次方項

# %%
from sklearn.preprocessing import PolynomialFeatures

quadratic = PolynomialFeatures(degree=2)#0~2次方

x_train_poly = quadratic.fit_transform(x_train_std)
x_test_poly = quadratic.fit_transform(x_test_std)
x_poly = quadratic.fit_transform(x_std)

# %% [markdown]
# plot_learning_curve function

# %%
 # Scikit-Learn 官網作圖函式
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.datasets import load_digits
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit


def plot_learning_curve(estimator, title, x, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure(figsize=(10,6))  #調整作圖大小
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, x, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# 四、線性迴歸
#
# 多變項(多變數，但只有一次式)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train_std,y_train)
print('各變項參數:',lr.coef_)
print("MSE: %.2f"% np.mean((lr.predict(x_test_std)-y_test)**2))
print("R Square:",lr.score(x_test_std,y_test))
# Out:
# 各變項參數: [[ 2.33398371e+03 -2.01776468e+02  8.62692561e+02 -5.99839379e+01
#   -3.98593916e+01  1.89872199e+00 -4.74627392e+02  4.47181070e+02
#    5.31790769e+01 -5.31790769e+01  6.93784058e+00  7.62988006e+00
#    1.67183073e+01 -7.38758092e+01 -3.16235128e+01  8.86977794e+00
#   -7.85464127e+00  9.68033577e+01 -1.38367723e+01 -3.27793508e+01
#    6.02460460e+00 -2.39016668e+01  4.05926696e+01]]
# MSE: 871813.14
# R Square: 0.8805481907244289

# %%
from sklearn.model_selection import KFold

cv = KFold(n_splits=10,random_state=None,shuffle=True)
estimator = LinearRegression()

plot_learning_curve(estimator,"LinearRegression",x_std,y,cv=cv,train_sizes=np.linspace(0.2,1.0,5))
# Out:
# <module 'matplotlib.pyplot' from '/Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
#    2.10988831e+02 -3.43059034e+13 -3.43059034e+13 -1.16670685e+01
#   -2.58942081e+13 -1.78261059e+13 -1.88863200e+13 -2.64825240e+13
#   -1.98697060e+13 -1.40048414e+13 -2.03361057e+13 -1.40048414e+13
#   -1.63699707e+13 -1.98697060e+13 -1.80990837e+13  4.04125973e+12
#    6.90017651e+12  4.69152361e+13  1.01124398e+13  1.89753577e+13
#   -7.53727372e+13  1.60709934e+13  1.18615460e+13  5.87762916e+12
#    3.12096582e+13 -2.30878112e+13 -1.42571736e+13 -1.77305723e+12
#    2.48974373e+13  4.16509570e+12 -1.92837663e+13  4.00150596e+13
#    1.01124398e+13 -1.11540178e+13 -9.61144195e+13 -5.90430791e+12
#   -1.89523683e+13 -1.72418974e+13  1.49142332e+13 -4.67500202e+13
#   -3.05525985e+13 -2.08204439e+13  1.77791073e+12 -1.68942117e+13
#   -4.06543736e+13 -2.83715820e+00 -4.98936867e+13 -3.43478410e+13
#   -3.63906912e+13 -5.10272704e+13 -3.82855070e+13  3.33375162e+13
#    4.89009771e+13 -2.69849213e+13  2.76139110e+13 -3.82855070e+13
#    3.96542046e+13  7.08186875e+13  2.71514101e+13 -3.61563229e+13
#    1.45811745e+13 -4.11493289e+13 -2.72278281e+13 -1.64615559e+13
#    5.40020497e+13 -3.35054741e+13 -7.21517991e+12 -5.73830235e+13
#   -3.92301915e+12  4.23998950e+13 -2.26797401e+13 -9.54601569e+12
#   -1.56274525e+13  5.40636065e+12  5.09318440e+13  7.31887005e+13
#   -5.13300081e+13 -8.48349053e+12 -3.30527419e+13 -4.57381130e+12
#    1.54676518e+13  9.01287174e+13  1.51340751e+13  1.95980498e+13
#    6.34198598e+12  3.30534769e+13 -3.21618662e+13  9.74174241e+11
#   -1.04032945e+13 -3.00938729e+11 -1.60473592e+13  1.01738391e+14
#   -2.07083978e+12 -5.93286322e+13  4.97630985e+13 -2.36462661e+13
#    9.43316441e+12 -5.53783422e+13  1.57232351e+13  2.27601744e+13
#    3.73007751e+13 -1.07124254e+13  1.99128646e+13 -1.19249817e+13
#    7.00598366e+12 -2.18448891e+13  3.89394321e+12  1.82213792e+12
#   -9.69580920e+12  2.30364313e+13 -2.72835606e+13  4.82061455e+12
#    2.00770330e+12 -2.97978116e+13 -4.90488482e+12  9.63489850e+13
#   -1.37578384e+13  3.16499976e+13  4.05508059e+13  2.17652385e+13
#    3.36414264e+13 -4.51904338e+13  1.71056537e+12 -1.30893879e+13
#   -9.96842909e+12 -1.90955544e+13  2.16668642e+13 -9.67163986e+12
#    2.42325236e+13 -1.14513219e+13 -2.57908412e+13 -1.11424112e+13
#   -1.88128308e+13 -2.26331648e+13  1.18339455e+13  6.81905242e+12]]
# MSE: 2484019051855555595262230528.00
# R Square: -3.4034881548005625e+20

# %%
from sklearn.model_selection import KFold

cv = KFold(n_splits=10, random_state=None, shuffle=True)
estimator = LinearRegression()

plot_learning_curve(estimator, "Nonlinear Regression", x_poly, y, cv=cv, train_sizes=np.linspace(0.2, 1.0, 5))
# Out:
# <module 'matplotlib.pyplot' from '/Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>
# /Users/ethan/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
